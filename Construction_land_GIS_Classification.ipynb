tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(413).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(414).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(415).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(416).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(417).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(418).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(419).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(42).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(420).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(421).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(422).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(423).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(424).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(425).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(426).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(427).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(428).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(429).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(43).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(430).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(431).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(432).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(433).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(434).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(435).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(436).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(437).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(438).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(439).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(44).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(440).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(441).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(442).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(443).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(444).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(445).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(446).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(447).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(448).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(449).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(45).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(450).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(451).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(452).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(453).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(454).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(455).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(456).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(457).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(458).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(459).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(46).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(460).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(461).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(462).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(463).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(464).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(465).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(466).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(467).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(468).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(469).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(47).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(470).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(471).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/city_building/city_building(472).tif
# ...
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(868).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(869).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(87).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(870).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(871).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(872).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(873).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(874).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(875).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(876).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(877).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(878).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(879).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(88).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(880).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(881).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(882).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(883).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(884).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(885).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(886).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(887).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(888).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(889).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(89).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(890).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(891).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(892).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(893).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(894).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(895).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(896).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(897).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(898).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(899).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(9).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(90).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(900).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(901).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(902).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(903).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(904).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(905).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(906).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(907).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(908).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(909).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(91).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(910).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(911).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(912).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(913).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(914).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(915).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(916).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(917).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(918).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(919).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(92).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(920).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(921).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(922).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(923).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(924).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(925).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(926).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(927).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(928).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(929).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(93).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(930).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(931).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(932).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(933).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(934).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(935).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(936).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(937).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(938).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(939).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(94).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(940).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(941).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(942).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(943).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(944).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(945).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(946).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(947).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(948).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(949).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(95).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(950).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(951).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(952).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(953).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(954).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(955).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(956).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(957).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(958).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(959).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(96).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(960).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(961).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(962).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(963).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(964).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(965).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(966).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(967).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(968).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(969).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(97).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(970).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(971).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(972).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(973).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(974).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(975).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(976).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(977).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(978).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(979).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(98).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(980).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(981).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(982).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(983).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(984).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(985).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(986).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(987).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(988).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(989).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(99).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(990).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(991).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(992).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(993).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(994).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(995).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(996).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(997).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(998).tif
#   inflating: /content/drive/MyDrive/hyperspectral_data/constructionland/storage_room/storage_room(999).tif

# %%
EXTRACTED_DATA_PATH = "/content/drive/MyDrive/hyperspectral_data/constructionland"
TRAIN_SIZE = 0.7
VAL_SIZE = 0.15
TEST_SIZE = 0.15
BATCH_SIZE = 32
EPOCHS = 3

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

full_dataset = datasets.ImageFolder(root=EXTRACTED_DATA_PATH, transform=transform)
class_names = full_dataset.classes
print(f"Classes found: {class_names}")
# Out:
# Classes found: ['city_building', 'container', 'residents', 'storage_room']

# %%
class_counts = []
for dir in os.listdir(EXTRACTED_DATA_PATH):
  class_counts.append(len(os.listdir(os.path.join(EXTRACTED_DATA_PATH, dir))))

# %%
def plot_class_distribution(dataset, class_names):

    plt.figure(figsize=(8, 5))
    sns.barplot(x=class_names, y=class_counts, palette='viridis')
    plt.title("Class Distribution in Dataset")
    plt.ylabel("Number of Images")
    plt.xlabel("Classes")
    plt.show()

plot_class_distribution(full_dataset, class_names)
# Out:
# <ipython-input-8-a5ce7d6f2e3d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=class_counts, palette='viridis')

# %%
from torchvision.utils import make_grid
from torchvision.transforms.functional import to_pil_image

def show_sample_images(dataset, class_names, samples_per_class=3):
    """Display sample images from each class efficiently."""
    # ⚡ Check if dataset has 'targets' for quick indexing
    targets = dataset.targets if hasattr(dataset, 'targets') else [label for _, label in dataset]

    fig, axes = plt.subplots(len(class_names), samples_per_class, figsize=(samples_per_class * 3, len(class_names) * 3))
    fig.suptitle("Sample Images from Each Class", fontsize=16)

    for cls_idx, cls_name in enumerate(class_names):
        # ✅ Quickly find indices without scanning entire dataset
        class_indices = [i for i, t in enumerate(targets) if t == cls_idx][:samples_per_class]

        for j, img_idx in enumerate(class_indices):
            img, _ = dataset[img_idx]
            # ⚡ Faster un-normalization for display
            img = img * torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1) + torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
            img = torch.clamp(img, 0, 1)  # Clip values for valid range
            axes[cls_idx, j].imshow(img.permute(1, 2, 0).cpu().numpy())
            axes[cls_idx, j].axis('off')
            if j == 0:
                axes[cls_idx, j].set_ylabel(cls_name, rotation=0, labelpad=50, fontsize=12)

    plt.tight_layout()
    plt.show()

# 🚀 Run optimized function
show_sample_images(full_dataset, class_names)

# %%
total_size = len(full_dataset)
train_size = int(TRAIN_SIZE * total_size)
val_size = int(VAL_SIZE * total_size)
test_size = total_size - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

# %%
batch_size = BATCH_SIZE
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class CNNClassifier(nn.Module):
    def __init__(self, num_classes=3):
        super(CNNClassifier, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 32 * 32, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# %%
model = CNNClassifier(num_classes=len(class_names)).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# 🎯 Training and validation function
def train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS):
    best_val_acc = 0.0
    train_acc_list, val_acc_list, train_loss_list, val_loss_list = [], [], [], []
    for epoch in range(epochs):
        print(epoch)
        model.train()
        total_loss, correct, total = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_acc = correct / total
        train_acc_list.append(train_acc)
        train_loss_list.append(total_loss / len(train_loader))

        val_acc, val_loss = evaluate_model(model, val_loader, criterion)
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss)

        print(f"Epoch [{epoch+1}/{epochs}] - Loss: {total_loss:.4f} - Train Acc: {train_acc:.4f} - Val Acc: {val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), f'best_model_{model_name}.pth')

    return train_acc_list, val_acc_list, train_loss_list, val_loss_list

# %%
def evaluate_model(model, data_loader, criterion):
    model.eval()
    correct, total, total_loss = 0, 0, 0
    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total, total_loss / len(data_loader)

# %%
# 📊 Confusion Matrix visualization
def analyze_model(model, data_loader, model_name):
    y_true, y_pred = [], []
    model.eval()
    with torch.no_grad():
        for images, labels in data_loader:
            images = images.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())

    cm = confusion_matrix(y_true, y_pred, normalize='true')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, values_format=".2f")
    plt.title(f"Normalized Confusion Matrix - {model_name}")
    plt.show()

# %%
# 🏃‍♂️ Plot training analysis
def plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name):
    epochs = range(1, len(train_acc) + 1)
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    axs[0].plot(epochs, train_acc, 'bo-', label='Training Acc')
    axs[0].plot(epochs, val_acc, 'ro-', label='Validation Acc')
    axs[0].set_title(f'{model_name}: Accuracy per Epoch')
    axs[0].legend()

    axs[1].plot(epochs, train_loss, 'bo-', label='Training Loss')
    axs[1].plot(epochs, val_loss, 'ro-', label='Validation Loss')
    axs[1].set_title(f'{model_name}: Loss per Epoch')
    axs[1].legend()

    plt.show()

# %%
def get_pretrained_model(model_name, num_classes):
    if model_name == 'resnet50':
        model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
        num_ftrs = model.fc.in_features
        model.fc = nn.Linear(num_ftrs, num_classes)

    elif model_name == 'densenet121':
        model = models.densenet121(weights=models.DenseNet121_Weights.DEFAULT)
        num_ftrs = model.classifier.in_features
        model.classifier = nn.Linear(num_ftrs, num_classes)

    elif model_name == 'efficientnet_b0':
        model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
        num_ftrs = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(num_ftrs, num_classes)

    else:
        raise ValueError(f"Unsupported model: {model_name}")

    # Freeze feature extractor
    for param in model.parameters():
        param.requires_grad = False

    # Only classifier layers are trainable
    for param in model.fc.parameters() if hasattr(model, 'fc') else model.classifier.parameters():
        param.requires_grad = True

    return model.to(device)

# %%
# 🚀 Compare models
models_to_compare = ['custom', 'densenet121', 'efficientnet_b0','resnet50']
results = {}

for model_name in models_to_compare:
    print(f"\n🚀 Training model: {model_name}")
    if model_name == 'custom':
      model = CNNClassifier(num_classes=len(class_names)).to(device)
      criterion = nn.CrossEntropyLoss()
      optimizer = optim.Adam(model.parameters(), lr=0.001)
      train_acc, val_acc, train_loss, val_loss = train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS)
      model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
      test_acc, _ = evaluate_model(model, test_loader, criterion)
      print(f"✅ Test Accuracy ({model_name}): {test_acc:.4f}")
      analyze_model(model, test_loader, model_name)
      plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name)

      results[model_name] = {'train_acc': train_acc, 'val_acc': val_acc, 'test_acc': test_acc}
    else:
      model = get_pretrained_model(model_name, num_classes=len(class_names))
      criterion = nn.CrossEntropyLoss()
      optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)

      train_acc, val_acc, train_loss, val_loss = train_model(model, criterion, optimizer, train_loader, val_loader, model_name, epochs=EPOCHS)
      model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
      test_acc, _ = evaluate_model(model, test_loader, criterion)
      print(f"✅ Test Accuracy ({model_name}): {test_acc:.4f}")

      analyze_model(model, test_loader, model_name)
      plot_training_analysis(train_acc, val_acc, train_loss, val_loss, model_name)

      results[model_name] = {'train_acc': train_acc, 'val_acc': val_acc, 'test_acc': test_acc}

# 🏆 Final Test Accuracy Summary
for model_name, result in results.items():
    print(f"🏅 {model_name} - Final Test Accuracy: {result['test_acc']:.4f}")
# Out:
# 🚀 Training model: custom
# 0
# Epoch [1/3] - Loss: 76.9343 - Train Acc: 0.6027 - Val Acc: 0.8433
# 1
# Epoch [2/3] - Loss: 37.8577 - Train Acc: 0.8334 - Val Acc: 0.9261
# 2
# Epoch [3/3] - Loss: 25.8343 - Train Acc: 0.8986 - Val Acc: 0.9278
# <ipython-input-21-94ed3bc2314c>:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (custom): 0.9140
# 🚀 Training model: densenet121
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# 100%|██████████| 30.8M/30.8M [00:00<00:00, 78.2MB/s]
# 0
# Epoch [1/3] - Loss: 41.5073 - Train Acc: 0.8515 - Val Acc: 0.9665
# 1
# Epoch [2/3] - Loss: 13.1943 - Train Acc: 0.9631 - Val Acc: 0.9912
# 2
# Epoch [3/3] - Loss: 8.1086 - Train Acc: 0.9778 - Val Acc: 0.9930
# <ipython-input-21-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (densenet121): 0.9807
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 🚀 Training model: efficientnet_b0
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 93.7MB/s]
# 0
# Epoch [1/3] - Loss: 37.7794 - Train Acc: 0.8832 - Val Acc: 0.9718
# 1
# Epoch [2/3] - Loss: 13.0117 - Train Acc: 0.9676 - Val Acc: 0.9771
# 2
# Epoch [3/3] - Loss: 10.5186 - Train Acc: 0.9653 - Val Acc: 0.9859
# <ipython-input-21-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (efficientnet_b0): 0.9877
# 🚀 Training model: resnet50
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 120MB/s]
# 0
# Epoch [1/3] - Loss: 39.7874 - Train Acc: 0.9114 - Val Acc: 0.9613
# 1
# Epoch [2/3] - Loss: 13.0370 - Train Acc: 0.9755 - Val Acc: 0.9789
# 2
# Epoch [3/3] - Loss: 9.0417 - Train Acc: 0.9834 - Val Acc: 0.9824
# <ipython-input-21-94ed3bc2314c>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'best_model_{model_name}.pth'))
# ✅ Test Accuracy (resnet50): 0.9825
# 🏅 custom - Final Test Accuracy: 0.9140
# 🏅 densenet121 - Final Test Accuracy: 0.9807
# 🏅 efficientnet_b0 - Final Test Accuracy: 0.9877
# 🏅 resnet50 - Final Test Accuracy: 0.9825
